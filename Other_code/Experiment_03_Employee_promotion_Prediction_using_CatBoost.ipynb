# %% [markdown]
# <H1>Problem Statement</H1>
# Your client is a large MNC and they have 9 broad verticals across the organisation. One of the problem your client is facing is around identifying the right people for promotion (only for manager position and below) and prepare them in time. Currently the process, they are following is:
#
# They first identify a set of employees based on recommendations/ past performance
# Selected employees go through the separate training and evaluation program for each vertical. These programs are based on the required skill of each vertical
# At the end of the program, based on various factors such as training performance, KPI completion (only employees with KPIs completed greater than 60% are considered) etc., employee gets promotion
# For above mentioned process, the final promotions are only announced after the evaluation and this leads to delay in transition to their new roles. Hence, company needs your help in identifying the eligible candidates at a particular checkpoint so that they can expedite the entire promotion cycle.
#
# They have provided multiple attributes around Employee's past and current performance along with demographics. Now, The task is to predict whether a potential promotee at checkpoint in the test set will be promoted or not after the evaluation process.

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# Preconfiguring packages ...
# Selecting previously unselected package cron.
# (Reading database ... 18408 files and directories currently installed.)
# Preparing to unpack .../00-cron_3.0pl1-128ubuntu5_amd64.deb ...
# Unpacking cron (3.0pl1-128ubuntu5) ...
# Selecting previously unselected package libapparmor1:amd64.
# Preparing to unpack .../01-libapparmor1_2.11.0-2ubuntu17.1_amd64.deb ...
# Unpacking libapparmor1:amd64 (2.11.0-2ubuntu17.1) ...
# Selecting previously unselected package libdbus-1-3:amd64.
# Preparing to unpack .../02-libdbus-1-3_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Selecting previously unselected package dbus.
# Preparing to unpack .../03-dbus_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking dbus (1.10.22-1ubuntu1) ...
# Selecting previously unselected package dirmngr.
# Preparing to unpack .../04-dirmngr_2.1.15-1ubuntu8.1_amd64.deb ...
# Unpacking dirmngr (2.1.15-1ubuntu8.1) ...
# ...

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
# !cp  /content/drive/Hackthon/WNS/* .
# !ls -l
# Out:
# total 6696
# -rw-r--r-- 1 root root    2495 Sep 15 20:29 adc.json
# drwxr-xr-x 2 root root    4096 Sep 15 20:30 drive
# drwxr-xr-x 2 root root    4096 Sep 13 17:28 sample_data
# -rw-r--r-- 1 root root 1565147 Sep 15 20:30 test_2umaH9m.csv
# -rw-r--r-- 1 root root 3759647 Sep 15 20:30 train_LZdllcl.csv
# -rw-r--r-- 1 root root     229 Sep 15 20:30 Untitled
# -rw-r--r-- 1 root root  202021 Sep 15 20:30 WNS_Traine_01.ipynb
# -rw-r--r-- 1 root root 1178424 Sep 15 20:30 WNS_Traine_02.ipynb
# -rw-r--r-- 1 root root   57567 Sep 15 20:30 WNS_Traine_03.ipynb
# -rw-r--r-- 1 root root   62664 Sep 15 20:30 WNS_Traine_04.ipynb

# %%
# !ls -l
# Out:
# total 6696
# -rw-r--r-- 1 root root    2495 Sep 15 20:29 adc.json
# drwxr-xr-x 2 root root    4096 Sep 15 20:30 drive
# drwxr-xr-x 2 root root    4096 Sep 13 17:28 sample_data
# -rw-r--r-- 1 root root 1565147 Sep 15 20:30 test_2umaH9m.csv
# -rw-r--r-- 1 root root 3759647 Sep 15 20:30 train_LZdllcl.csv
# -rw-r--r-- 1 root root     229 Sep 15 20:30 Untitled
# -rw-r--r-- 1 root root  202021 Sep 15 20:30 WNS_Traine_01.ipynb
# -rw-r--r-- 1 root root 1178424 Sep 15 20:30 WNS_Traine_02.ipynb
# -rw-r--r-- 1 root root   57567 Sep 15 20:30 WNS_Traine_03.ipynb
# -rw-r--r-- 1 root root   62664 Sep 15 20:30 WNS_Traine_04.ipynb

# %%
# !pip install catboost
# !pip install ipywidgets
# !pip install lightgbm
# !pip install xgboost
# Out:
# ...
#     100% |████████████████████████████████| 58.6MB 771kB/s
# ...
#     100% |████████████████████████████████| 112kB 5.9MB/s
# ...
#     100% |████████████████████████████████| 2.2MB 1.5MB/s
# ...
#     100% |████████████████████████████████| 737kB 18.6MB/s
# ...

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>
# <h3>3.1. Import All required Classed first</h3>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt


from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix,roc_auc_score,mean_squared_error,f1_score,recall_score,precision_score
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.cross_validation import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer
from numpy import argmax
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier,VotingClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier, Pool, cv
from lightgbm import LGBMClassifier

# %%
SEED = 0

# %%
Data = pd.read_csv("train_LZdllcl.csv")

# %%
print(Data.shape)
print(Data.columns)
# Out:
# (54808, 14)
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
print(Data.describe())
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score  \
# count       54808.000000   54808.000000  54808.000000        54808.000000
# mean            5.865512       0.351974      0.023172           63.386750
# std             4.265094       0.477590      0.150450           13.371559
# ...

# %%
Data.count()
# Out:
# employee_id             54808
# department              54808
# region                  54808
# education               52399
# gender                  54808
# recruitment_channel     54808
# no_of_trainings         54808
# age                     54808
# previous_year_rating    50684
# length_of_service       54808
# KPIs_met >80%           54808
# awards_won?             54808
# avg_training_score      54808
# is_promoted             54808
# dtype: int64

# %%
values={"previous_year_rating":3,"education":"O"}
Data.fillna(value=values,inplace=True)

# %%
Data.isna().values.any()
# Out:
# False

# %%
print(len(Data))
print(len(Data.loc[Data["is_promoted"]==0]))
print(len(Data.loc[Data["is_promoted"]==1]))
print(len(Data))
# Out:
# 54808
# 50140
# 4668
# 54808

# %%
50140/54808*100
# Out:
# 91.48299518318494

# %%
Data.count()
# Out:
# employee_id             54808
# department              54808
# region                  54808
# education               54808
# gender                  54808
# recruitment_channel     54808
# no_of_trainings         54808
# age                     54808
# previous_year_rating    54808
# length_of_service       54808
# KPIs_met >80%           54808
# awards_won?             54808
# avg_training_score      54808
# is_promoted             54808
# dtype: int64

# %%
Data.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
#data_xs = Data.drop(['employee_id',"is_promoted","education"],axis=1)
data_xs = Data.drop(['employee_id',"is_promoted"],axis=1)
#data_xs = Data.drop(['employee_id',"is_promoted","gender","recruitment_channel","region"],axis=1)

# %%
data_xs.head()
# Out:
#           department     region         education gender recruitment_channel  \
# 0  Sales & Marketing   region_7  Master's & above      f            sourcing
# 1         Operations  region_22        Bachelor's      m               other
# 2  Sales & Marketing  region_19        Bachelor's      m            sourcing
# 3  Sales & Marketing  region_23        Bachelor's      m               other
# 4         Technology  region_26        Bachelor's      m               other
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   35                   5.0                  8
# 1                1   30                   5.0                  4
# 2                1   34                   3.0                  7
# 3                2   39                   1.0                 10
# 4                1   45                   3.0                  2
#
#    KPIs_met >80%  awards_won?  avg_training_score
# 0              1            0                  49
# ...

# %%
categorical_features_indices = np.array([0,1,2,3,4,6,8,10,11])
#categorical_features_indices = np.array([0,1,3,6,7])

# %%
def model_evalution(model):
  print("####################### model Evalution started #######################")
  train_pre = model.predict(x_train)
  test_pre = model.predict(x_test)
  train_pro = model.predict_proba(x_train)
  test_pro = model.predict_proba(x_test)
  
  print("Train Accuracy: {0} \t Test Accuracy: {1}".format(accuracy_score(y_train, train_pre),accuracy_score(y_test,test_pre)))
  print("Train Loss: {0} \t Test Loss: {1}".format(mean_squared_error(y_train, train_pre),mean_squared_error(y_test,test_pre)))
  print("Train AUC: {0} \t Test AUC: {1}".format(roc_auc_score(y_train, train_pro[:,1]),roc_auc_score(y_test,test_pro[:,1])))
  print("Train F1: {0} \t Test F1: {1}".format(f1_score(y_train, train_pre),f1_score(y_test,test_pre)))
  print("Train recall: {0} \t Test recall: {1}".format(recall_score(y_train, train_pre),recall_score(y_test,test_pre)))
  print("Train precision: {0} \t Test Precision: {1}".format(precision_score(y_train, train_pre),precision_score(y_test,test_pre)))
  print("Train Confusion Matrix: \n{0} \n Test Confusion Matrix: \n{1}".format(confusion_matrix(y_train, train_pre),confusion_matrix(y_test,test_pre)))
  #f1_score

# %%
x_train,x_test,y_train,y_test = train_test_split(data_xs,Data["is_promoted"], test_size = 0.3,random_state=20)

# %%
params = {'iterations':[200],
          "loss_function":["Logloss"],
          'eval_metric':["Accuracy"],
          'learning_rate':[1,0.5],
          'depth':[2,3,4],
          'verbose':[True],
          'class_weights':[[1,2],[1,3]],
          #'l2_leaf_reg':[10,30,50,100],
          #'bagging_temperature':[0.0,0.2,0.5,0.8],
         }

# %%
rf_model = CatBoostClassifier()
grid = GridSearchCV(rf_model,params,verbose=True,return_train_score=True,cv=2)
grid.fit(x_train, y_train,
         cat_features=categorical_features_indices,
         eval_set=(x_test, y_test),)
print(grid.best_params_)
model_evalution(grid)

# %%
del(catboost_model)

# %%
#catboost_model = CatBoostClassifier(class_weights=[1,9])
#catboost_model = CatBoostClassifier(loss_function="Logloss",iterations=200,verbose=True,
#                                    eval_metric="TotalF1",learning_rate=0.5,class_weights=[1,3],depth=3,
#                                    l2_leaf_reg=100,
#                                    #bagging_temperature=0.2,
#                                    bootstrap_type="Bernoulli",subsample=0.8 
#                                   )
catboost_model = CatBoostClassifier(iterations=2000,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5) #--->0.5139
catboost_model.fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
#catboost_model.fit(x_train, y_train,cat_features=categorical_features_indices)
model_evalution(catboost_model)

# %%
catboost_model_1 = CatBoostClassifier(iterations=100,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_1)

catboost_model_2 = CatBoostClassifier(iterations=200,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_2)

catboost_model_3 = CatBoostClassifier(iterations=300,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_3)

catboost_model_4 = CatBoostClassifier(iterations=400,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_4)

catboost_model_5 = CatBoostClassifier(iterations=500,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_5)

catboost_model_6 = CatBoostClassifier(iterations=600,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_6)

catboost_model_7 = CatBoostClassifier(iterations=500,verbose=True,eval_metric="Logloss",learning_rate=0.2,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_7)

catboost_model_8 = CatBoostClassifier(iterations=500,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=200,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_8)
catboost_model_9 = CatBoostClassifier(iterations=500,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.2
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_9)

catboost_model_10 = CatBoostClassifier(iterations=500,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=200,bagging_temperature=0.2
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_10)

catboost_model_11 = CatBoostClassifier(iterations=100,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_11)

catboost_model_12 = CatBoostClassifier(iterations=150,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_12)
catboost_model_13 = CatBoostClassifier(iterations=200,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_13)

catboost_model_14 = CatBoostClassifier(iterations=250,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_14)

catboost_model_15 = CatBoostClassifier(iterations=300,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_15)

catboost_model_16 = CatBoostClassifier(iterations=350,verbose=True,eval_metric="Logloss",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_16)
# Out:
# 0:	learn: 0.4975272	test: 0.4982819	best: 0.4982819 (0)	total: 86.6ms	remaining: 8.57s
# 1:	learn: 0.4463426	test: 0.4463089	best: 0.4463089 (1)	total: 167ms	remaining: 8.16s
# 2:	learn: 0.3609641	test: 0.3586773	best: 0.3586773 (2)	total: 249ms	remaining: 8.05s
# 3:	learn: 0.3260991	test: 0.3213092	best: 0.3213092 (3)	total: 332ms	remaining: 7.97s
# 4:	learn: 0.3194751	test: 0.3138806	best: 0.3138806 (4)	total: 403ms	remaining: 7.65s
# 5:	learn: 0.3163311	test: 0.3112198	best: 0.3112198 (5)	total: 477ms	remaining: 7.48s
# 6:	learn: 0.3093275	test: 0.3045904	best: 0.3045904 (6)	total: 556ms	remaining: 7.39s
# 7:	learn: 0.3063384	test: 0.3016275	best: 0.3016275 (7)	total: 637ms	remaining: 7.33s
# 8:	learn: 0.3033986	test: 0.2977108	best: 0.2977108 (8)	total: 713ms	remaining: 7.21s
# 9:	learn: 0.3025920	test: 0.2969433	best: 0.2969433 (9)	total: 780ms	remaining: 7.02s
# 10:	learn: 0.3019105	test: 0.2957152	best: 0.2957152 (10)	total: 851ms	remaining: 6.88s
# ...

# %%
catboost_model_1 = CatBoostClassifier(iterations=100,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_1)

catboost_model_2 = CatBoostClassifier(iterations=200,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_2)

catboost_model_3 = CatBoostClassifier(iterations=300,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_3)

catboost_model_4 = CatBoostClassifier(iterations=400,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_4)

catboost_model_5 = CatBoostClassifier(iterations=500,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_5)

catboost_model_6 = CatBoostClassifier(iterations=600,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_6)

catboost_model_7 = CatBoostClassifier(iterations=500,verbose=True,eval_metric="F1",learning_rate=0.2,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_7)

catboost_model_8 = CatBoostClassifier(iterations=500,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=200,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_8)
catboost_model_9 = CatBoostClassifier(iterations=500,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.2
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_9)

catboost_model_10 = CatBoostClassifier(iterations=500,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=200,bagging_temperature=0.2
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_10)

catboost_model_11 = CatBoostClassifier(iterations=100,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_11)

catboost_model_12 = CatBoostClassifier(iterations=150,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_12)
catboost_model_13 = CatBoostClassifier(iterations=200,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_13)

catboost_model_14 = CatBoostClassifier(iterations=250,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_14)

catboost_model_15 = CatBoostClassifier(iterations=300,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_15)

catboost_model_16 = CatBoostClassifier(iterations=350,verbose=True,eval_metric="F1",learning_rate=0.5,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.5
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model_16)
# Out:
# 0:	learn: 0.2021825	test: 0.2112933	best: 0.2112933 (0)	total: 83.4ms	remaining: 8.25s
# 1:	learn: 0.2671529	test: 0.2669845	best: 0.2669845 (1)	total: 165ms	remaining: 8.08s
# 2:	learn: 0.4852305	test: 0.5083319	best: 0.5083319 (2)	total: 254ms	remaining: 8.2s
# 3:	learn: 0.4998874	test: 0.5143759	best: 0.5143759 (3)	total: 346ms	remaining: 8.29s
# 4:	learn: 0.5265271	test: 0.5427236	best: 0.5427236 (4)	total: 436ms	remaining: 8.28s
# 5:	learn: 0.5234493	test: 0.5425318	best: 0.5427236 (4)	total: 519ms	remaining: 8.14s
# 6:	learn: 0.5291583	test: 0.5405133	best: 0.5427236 (4)	total: 597ms	remaining: 7.94s
# 7:	learn: 0.5249026	test: 0.5356962	best: 0.5427236 (4)	total: 689ms	remaining: 7.92s
# 8:	learn: 0.5263841	test: 0.5354065	best: 0.5427236 (4)	total: 779ms	remaining: 7.88s
# 9:	learn: 0.5264678	test: 0.5351159	best: 0.5427236 (4)	total: 869ms	remaining: 7.82s
# 10:	learn: 0.5269392	test: 0.5318644	best: 0.5427236 (4)	total: 954ms	remaining: 7.72s
# ...

# %%
del(catboost_model)

# %%
catboost_model = CatBoostClassifier(iterations=1000,verbose=True,eval_metric="Logloss",learning_rate=0.1,class_weights=[1,3],depth=3,l2_leaf_reg=50,bagging_temperature=0.2
                                   ).fit(x_train, y_train,cat_features=categorical_features_indices,eval_set=(x_test, y_test))
model_evalution(catboost_model)
# Out:
# 0:	learn: 0.6394422	test: 0.6395292	best: 0.6395292 (0)	total: 136ms	remaining: 2m 16s
# 1:	learn: 0.5915719	test: 0.5916488	best: 0.5916488 (1)	total: 284ms	remaining: 2m 21s
# 2:	learn: 0.5601173	test: 0.5602478	best: 0.5602478 (2)	total: 405ms	remaining: 2m 14s
# 3:	learn: 0.5312148	test: 0.5312821	best: 0.5312821 (3)	total: 538ms	remaining: 2m 13s
# 4:	learn: 0.5092464	test: 0.5092331	best: 0.5092331 (4)	total: 649ms	remaining: 2m 9s
# 5:	learn: 0.4903069	test: 0.4900335	best: 0.4900335 (5)	total: 774ms	remaining: 2m 8s
# 6:	learn: 0.4492504	test: 0.4485414	best: 0.4485414 (6)	total: 904ms	remaining: 2m 8s
# 7:	learn: 0.4257434	test: 0.4236924	best: 0.4236924 (7)	total: 1.03s	remaining: 2m 7s
# 8:	learn: 0.4105738	test: 0.4084822	best: 0.4084822 (8)	total: 1.16s	remaining: 2m 7s
# 9:	learn: 0.3960569	test: 0.3932733	best: 0.3932733 (9)	total: 1.27s	remaining: 2m 6s
# 10:	learn: 0.3779156	test: 0.3749639	best: 0.3749639 (10)	total: 1.38s	remaining: 2m 3s
# ...

# %%
catboost_model.feature_importances_
# Out:
# array([12.80526622,  1.69504816,  0.61016716,  0.19838307,  0.21137664,
#         0.341655  ,  1.06520206,  8.04422283,  1.21461722, 39.37465558,
#         2.04434222, 32.39506383])

# %%
cat_features=categorical_features_indices,eval_set=(x_test, y_test)

# %%
Data_test = pd.read_csv("test_2umaH9m.csv")

# %%
print(Data_test.shape)
print(Data_test.columns)
# Out:
# (23490, 13)
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score'],
#       dtype='object')

# %%
print(Data_test.describe())
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  23490.000000     23490.000000  23490.000000          21678.000000
# mean   39041.399149         1.254236     34.782929              3.339146
# std    22640.809201         0.600910      7.679492              1.263294
# min        3.000000         1.000000     20.000000              1.000000
# 25%    19370.250000         1.000000     29.000000              3.000000
# 50%    38963.500000         1.000000     33.000000              3.000000
# 75%    58690.000000         1.000000     39.000000              4.000000
# max    78295.000000         9.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score
# count       23490.000000   23490.000000  23490.000000        23490.000000
# mean            5.810387       0.358834      0.022776           63.263133
# std             4.207917       0.479668      0.149191           13.411750
# ...

# %%
Data.count()
# Out:
# employee_id             54808
# department              54808
# region                  54808
# education               54808
# gender                  54808
# recruitment_channel     54808
# no_of_trainings         54808
# age                     54808
# previous_year_rating    54808
# length_of_service       54808
# KPIs_met >80%           54808
# awards_won?             54808
# avg_training_score      54808
# is_promoted             54808
# dtype: int64

# %%
values={"previous_year_rating":3,"education":"O"}
Data_test.fillna(value=values,inplace=True)

# %%
Data_test.isna().values.any()
# Out:
# False

# %%
Data_test.count()
# Out:
# employee_id             23490
# department              23490
# region                  23490
# education               23490
# gender                  23490
# recruitment_channel     23490
# no_of_trainings         23490
# age                     23490
# previous_year_rating    23490
# length_of_service       23490
# KPIs_met >80%           23490
# awards_won?             23490
# avg_training_score      23490
# dtype: int64

# %%
Data_test.head()
# Out:
#    employee_id         department     region   education gender  \
# 0         8724         Technology  region_26  Bachelor's      m
# 1        74430                 HR   region_4  Bachelor's      f
# 2        72255  Sales & Marketing  region_13  Bachelor's      m
# 3        38562        Procurement   region_2  Bachelor's      f
# 4        64486            Finance  region_29  Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   3.0
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 0                  1              1            0                  77
# ...

# %%
data_test_xs = Data_test.drop(['employee_id'],axis=1)
#data_test_xs = Data_test.drop(['employee_id',"education","gender","recruitment_channel","region"],axis=1)

# %%
y_test_pre = catboost_model.predict(data_test_xs)

# %%
Data_test["is_promoted"] = y_test_pre

# %%
Data_test.to_csv("WNS_catBoost_Test_w_1_3_1000_lr_0_2_l2_50.csv",columns=["employee_id","is_promoted"],index=False)
#Data_test.to_csv("WNS.csv",index=False)

# %%
from google.colab import files
files.download("WNS_catBoost_Test_w_1_3_1000_lr_0_2_l2_50.csv")
#files.download("WNS.csv")
